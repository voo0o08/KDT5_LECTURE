# %% [markdown]
# # Naver 리뷰 데이터 전처리
# - train : https://raw.githubusercontent.com/e9t/nsmc/master/ratings_train.txt
# - test : https://raw.githubusercontent.com/e9t/nsmc/master/ratings_test.txt

# %% [markdown]
# # 데이터 준비

# %%
# urllib -> urlopen -> urlretrieve
from urllib.request import urlretrieve

filename = "../data/ratings_test.txt"
url = "https://raw.githubusercontent.com/e9t/nsmc/master/ratings_test.txt"

ret = urlretrieve(url, filename)
ret # 파일을 확인하면 html 파일임
# Out:
# ('../data/ratings_test.txt', <http.client.HTTPMessage at 0x1fb218dd910>)

# %%
import pandas as pd
reviewDF = pd.read_table(filename, usecols=[1, 2])
reviewDF.head()
# Out:
#                                             document  label
# 0                                                굳 ㅋ      1
# 1                               GDNTOPCLASSINTHECLUB      0
# 2             뭐야 이 평점들은.... 나쁘진 않지만 10점 짜리는 더더욱 아니잖아      0
# 3                   지루하지는 않은데 완전 막장임... 돈주고 보기에는....      0
# 4  3D만 아니었어도 별 다섯 개 줬을텐데.. 왜 3D로 나와서 제 심기를 불편하게 하죠??      0

# %% [markdown]
# # 2. 데이터 전처리
# - 결측치, 중복 데이터
# - 분류이기 때문에 클래스 균형 맞는지 확인
# - 텍스트 데이터 전처리 => 정제(불용어, 노이즈 제거), 토큰화, 2차 정제 => 단어사전
# - 텍스트 데이터 인코딩
# - 텍스트 데이터 패딩

# %%
# # 결측치 확인
# reviewDF.dropna(inplace=True)
# reviewDF.info()

# %%
# 중복 행 제거
reviewDF.drop_duplicates(inplace=True)
reviewDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49206 entries, 0 to 49999
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   document  49204 non-null  object
#  1   label     49206 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 1.1+ MB

# %%
# 클래스 균형 확인
reviewDF["label"].value_counts() # 이만하면 균형...
# Out:
# label
# 1    24735
# 0    24471
# Name: count, dtype: int64

# %%
# 피쳐와 레이블 분리
documentDF = reviewDF["document"].to_frame()
labelSR = reviewDF["label"]

print(f"documentDF.shape: {documentDF.shape}")
print(f"targetSR.shape: {labelSR.shape}")
# Out:
# documentDF.shape: (49206, 1)
# targetSR.shape: (49206,)

# %%
# 노이즈 데이터 기준 : 한글만?

# %%
# # 구두점 제거
# import string, re
# 
# punc = string.punctuation
# 
# def remove_punctuation(text):
#     # 정규 표현식을 사용하여 구두점 제거
#     punctuation_pattern = '[' + re.escape(string.punctuation) + ']'
#     text = re.sub(punctuation_pattern, '', text)
#     return text
# 
# # document 컬럼에 구두점 제거 함수 적용
# documentDF['document'] = documentDF['document'].apply(remove_punctuation)
# 
# # 결과 출력
# print(documentDF)

# %%
import string

stop_word = string.punctuation # 조사들 추가해야함
hangule_pattern = "[^ㄱ-ㅎㅏ-ㅣ가-힣 ]"

# %%
# Lemmatization이 더 정확함(기본 사전형 단어 의미)

# %%
documentDF["document"] = documentDF["document"].str.replace(hangule_pattern, "",regex=True)
documentDF[:5]
# Out:
#                                     document
# 0                                        굳 ㅋ
# 1
# 2           뭐야 이 평점들은 나쁘진 않지만 점 짜리는 더더욱 아니잖아
# 3                  지루하지는 않은데 완전 막장임 돈주고 보기에는
# 4  만 아니었어도 별 다섯 개 줬을텐데 왜 로 나와서 제 심기를 불편하게 하죠

# %%
import numpy as np

# regex = True => 정규식 적용
documentDF["document"] = documentDF["document"].str.replace("^ +", "", regex=True) # 스페이스는 몇개가오든 포함 안함
documentDF["document"].replace("",np.nan, inplace=True)
print(documentDF.isnull().sum())
# Out:
# document    315
# dtype: int64

# %% [markdown]
# https://gist.githubusercontent.com/chulgil/d10b18575a73778da4bc83853385465c/raw/a1a451421097fa9a93179cb1f1f0dc392f1f9da9/stopwords.txt
#
# stopword 파일로 저장하기

# %%
documentDF.dropna(inplace=True)
documentDF["document"].isnull().sum()
# Out:
# 0

# %%
hangul_stopword = "https://gist.githubusercontent.com/chulgil/d10b18575a73778da4bc83853385465c/raw/a1a451421097fa9a93179cb1f1f0dc392f1f9da9/stopwords.txt"

# %%
urlretrieve(hangul_stopword, "../data/stop_word.txt")
# Out:
# ('../data/stop_word.txt', <http.client.HTTPMessage at 0x1fb229a80d0>)

# %%
# 토큰 나누기
# 오크, 키위, 뽀로로...
from konlpy.tag import Okt  

# 형태소 분석기 인스턴스 생성
okt = Okt()

# 문장 합치기 (반복문 / 파일에 다 쓰기 ... 뭐 아무렇게나 통으로 -> 왜? Okt가 str외에 다른 형태는 안받음)
vocab = {}
for idx in range(documentDF.shape[0]):
    result = okt.morphs(documentDF.iloc[idx][0])
    for word in result:
        if len(word) >= 2:
            if word in vocab.keys():
                vocab[word] += 1
            else:
                vocab[word] = 1
print(vocab)
# Out:
# {'평점': 2213, '나쁘진': 12, '않지만': 46, '더욱': 94, '아니잖아': 29, '지루하지는': 4, '않은데': 24, '완전': 813, '막장': 228, '주고': 197, '보기': 552, '에는': 355, '아니었어도': 6, '다섯': 36, '줬을텐데': 2, '나와서': 133, '심기': 1, '불편하게': 10, '하죠': 7, '음악': 390, '주가': 16, '최고': 1950, '영화': 17234, '진정한': 108, '쓰레기': 1068, '마치': 68, '미국': 216, '애니': 293, '에서': 2331, '튀어나온듯': 1, '창의력': 2, '없는': 1200, '로봇': 36, '디자인': 19, '부터가': 27, '고개': 13, '젖게': 2, '한다': 461, '갈수록': 189, '개판': 59, '되가는': 1, '중국영화': 28, '유치하고': 74, '내용': 1347, '없음': 304, '잡다': 2, '끝남': 23, '안되는': 192, '무기': 25, '유치한': 58, '남무': 1, '그립다': 26, '동사서독': 2, '같은': 853, '이건': 876, '류작': 24, '이다': 1650, '이별': 20, '아픔': 40, '찾아오는': 3, '새로운': 86, '인연': 20, '기쁨': 7, '모든': 398, '사람': 1641, '그렇지는': 3, '않네': 14, '괜찮네요': 29, '오랜': 261, '포켓몬스터': 4, '잼밌': 1, '한국': 450, '독립영화': 69, '한계': 50, '그렇게': 215, '아버지': 123, '된다와': 1, '비교': 154, '청춘': 66, '아름답다': 62, '아름다': 42, '이성': 12, '흔들어': 4, '놓는다': 2, '찰나': 4, '포착': 2, '섬세하고': 10, '아름다운': 256, '수채화': 6, '퀴어': 8, '보이는': 62, '반전': 480, '이었지만': 13, '흡인': 5, '사라지지': 4, '않았다': 64, '스토리': 1696, '연출': 707, '연기': 2161, '비주': 46, '기본': 46, '조차': 90, '안된': 10, '무슨': 528, '이런': 1749, '찍고도': 1, '김문옥': 1, '감독': 1411, '경력': 9, '인데': 662, '조무래기': 2, '평론': 8, '마인드': 19, '빠져있겠지': 1, '소위': 3, '가라': 17, '발연기': 126, '도저히': 71, '보겠다': 37, '진짜': 2927, '이렇게': 787, '할거라곤': 2, '상상': 108, '했네': 34, '나이스': 1, '재미': 1306, '없는거': 14, '우려': 44, '먹어': 6, '챔프': 1, '방송': 147, '몇번': 119, '했더라': 3, 'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ': 14, '금요일': 10, '나이트메어': 5, '시리즈': 360, '함께': 187, '가장': 393, '많은': 316, '양산': 5, '해냈던': 1, '헬레': 1, '작가': 279, '상상력': 67, '돋보이는': 34, '작품': 1007, '이며': 70, '갈고리': 1, '사지': 9, '찢는': 2, '고어씬': 1, '지금': 738, '보더': 11, '라도': 143, '상당히': 127, '잔인하고': 15, '충격': 180, '나름': 278, '교훈': 120, '돋기는': 1, '하지만': 426, '어쩔': 99, '수없이': 13, '받을수밖에': 1, '섹스': 68, '코미디': 367, '재밌게': 656, '였다': 325, '민주화': 9, '시대': 217, '억눌린': 3, '영혼': 40, '관음': 2, '욕구': 12, '분출': 1, '인상': 211, '일본': 324, '천황': 4, '으로부터': 13, '받은': 46, '면죄부': 2, '긴박한': 11, '과정': 80, '루즈': 24, '하고': 1487, '지저분하게': 1, '늘어놓았다': 1, '괜히': 89, '나올': 86, '어미': 3, '건드려서': 2, '긁어': 1, '부스': 3, '만들었다는': 7, '아래': 37, '보이던데': 1, '제대로': 228, '봤네': 36, '까지면서': 1, '새끼': 107, '나오려': 1, '했음': 90, '그냥': 1351, '가면': 50, '한테': 263, '당했을': 1, '것임': 8, '뻔했으니': 1, '작살': 11, '밖에': 281, '없었다': 154, '번은': 34, '봤네요': 91, '어쩜': 31, '만들었을까': 30, '실화': 152, '라서': 123, '아름답고': 72, '찡하네요': 5, '많이': 648, '울었어요': 20, '벌써': 67, '이란': 268, '시간': 1279, '흘렀네요': 2, '노답': 61, '이네': 328, '년대': 237, '어린이': 73, '보고': 1551, '본받아라': 2, '까지': 1336, '마음': 506, '따뜻해지는': 41, '너무': 3735, '재밌다': 291, '안보': 131, '후회': 168, 'ㅠㅠ': 889, '점도': 284, '주기': 61, '싫어지는': 3, '배우': 1401, '이라는': 306, '이나': 545, '화판': 11, '봐으면': 1, '그리고': 626, '알바생': 16, '난다': 115, '정말': 3241, '표현': 340, '할수': 148, '성한': 42, '액션': 781, '시나리오': 226, '왜그러지': 4, '막판': 47, '대동단결': 2, '나올것': 4, '같다': 507, '없어요': 48, '아깝고': 39, '북괴': 8, '우리': 411, '주적': 2, 'ㅋㅋㅋ': 799, '난생처음': 8, '로그인': 29, '남기네요': 4, '빡쳐서': 12, '알바': 245, '속지': 21, '마세요': 150, '낭비': 121, '마이너스': 44, '오만': 7, '셰익스피어': 6, '이영화': 610, '한국영': 207, '특선': 6, '해서': 581, '봤다': 399, '개막': 41, '선정': 23, '되서': 53, '왤까': 1, '궁금': 7, '했었는데': 17, '봐도': 677, '이율': 1, '모르겠다': 175, '라는': 449, '밖에는': 14, '갑인듯': 4, '코헨': 1, '몰락': 7, '감동': 1631, '은빛': 3, '날개': 9, '조종사': 3, '보신': 28, '분들': 163, '이해': 642, '하시겟지만': 1, '입니다': 786, '졸작': 204, '솔직히말해': 1, '이유': 259, '엽기적인그녀': 3, '두고': 39, '메디': 80, '멜로': 111, '렷습': 2, '단시간': 2, '분안': 4, '소화': 15, '하려는': 37, '욕심': 32, '코믹': 184, '하다': 280, '채안': 1, '갑자기': 98, '생뚱맞': 3, '슬픈': 116, '깔리고': 1, '스타일': 98, '액션영화': 99, '굿굿': 38, '제임스': 23, '필드': 2, '먹고': 79, '파워': 21, '풀해': 1, '졌어': 1, 'ㅋㅋㅋㅋ': 334, '있으면': 60, '보단': 165, '더잘': 5, '만들겠': 1, '레이토': 2, '다미앙': 1, '시원한': 12, '어디': 145, '갔나': 5, 'ㅁㅊ': 13, '이딴': 202, '드라마': 1642, '라고': 633, '세계보건기구': 1, '발암': 11, '물질': 13, '올려야': 3, '극장': 293, '아무': 231, '기대': 335, '없이': 457, '들어갔다가': 1, '감탄': 66, '하면서': 168, '나왔는데': 19, '년도': 129, '였구나': 10, '아이디어': 27, '아주': 315, '좋다': 355, '재밌던데': 28, '왜케': 56, '낮지': 30, '역사': ...

# %%
len(vocab)
# Out:
# 52788

# %%
# 불용어 제거
stopwords_path = "../data/stop_word.txt"

# 파일 열기
with open(stopwords_path, encoding="utf-8") as f:
    stopwords = f.readlines()
stopwords = [word.strip() for word in stopwords]

# 데이터 제거
for sword in stopwords:
    if sword in vocab.keys():
        vocab.pop(sword)

# %%
len(vocab)
# Out:
# 52576

# %%
sorted(vocab.items(), key=lambda x: x[1], reverse=True)
# Out:
# [('영화', 17234),
#  ('너무', 3735),
#  ('정말', 3241),
#  ('진짜', 2927),
#  ('평점', 2213),
#  ('연기', 2161),
#  ('최고', 1950),
#  ('생각', 1824),
#  ('스토리', 1696),
#  ('이다', 1650),
#  ('드라마', 1642),
#  ('사람', 1641),
#  ('감동', 1631),
#  ('하는', 1574),
#  ('보고', 1551),
#  ('하고', 1487),
#  ('감독', 1411),
#  ('배우', 1401),
#  ('ㅋㅋ', 1384),
#  ('그냥', 1351),
#  ('내용', 1347),
#  ('재미', 1306),
#  ('보다', 1303),
#  ('없는', 1200),
#  ('봤는데', 1088),
#  ('쓰레기', 1068),
#  ('사랑', 1061),
#  ('작품', 1007),
#  ('다시', 954),
#  ('없다', 931),
#  ('마지막', 897),
#  ('ㅠㅠ', 889),
#  ('이건', 876),
#  ('같은', 853),
#  ('정도', 847),
#  ('있는', 836),
#  ('좋은', 820),
#  ('완전', 813),
#  ('처음', 813),
#  ('장면', 804),
#  ('주인공', 800),
#  ('ㅋㅋㅋ', 799),
#  ('이렇게', 787),
#  ('입니다', 786),
#  ('액션', 781),
#  ('최악', 755),
#  ('보는', 753),
#  ('이야기', 746),
#  ('지금', 738),
#  ('ㅡㅡ', 719),
#  ('연출', 707),
#  ('없고', 705),
#  ('느낌', 679),
#  ('봐도', 677),
#  ('별로', 672),
#  ('인데', 662),
#  ('재밌게', 656),
#  ('역시', 652),
#  ('많이', 648),
#  ('명작', 648),
#  ('이해', 642),
#  ('라고', 633),
#  ('때문', 619),
#  ('이영화', 610),
#  ('여자', 609),
#  ('해서', 581),
#  ('보면', 581),
#  ('보기', 552),
#  ('인생', 552),
#  ('이나', 545),
#  ('이고', 541),
#  ('수준', 523),
#  ('기억', 518),
#  ('아깝다', 512),
#  ('마음', 506),
#  ('결말', 500),
#  ('ㅎㅎ', 489),
#  ('반전', 480),
#  ('한번', 473),
#  ('현실', 470),
#  ('매력', 463),
#  ('가슴', 462),
#  ('한다', 461),
#  ('소재', 461),
#  ('하게', 458),
#  ('없이', 457),
#  ('남자', 453),
#  ('한국', 450),
#  ('라는', 449),
#  ('인간', 437),
#  ('전개', 434),
#  ('되는', 424),
#  ('만든', 421),
#  ('눈물', 418),
#  ('추천', 411),
#  ('자체', 408),
#  ('봤다', 399),
#  ('모든', 398),
#  ('가장', 393),
#  ('음악', 390),
#  ('모습', 387),
#  ('않고', 379),
#  ('합니다', 376),
#  ('인가', 373),
#  ('하지', 369),
#  ('계속', 368),
#  ('코미디', 367),
#  ('캐릭터', 366),
#  ('실망', 362),
#  ('인지', 362),
#  ('시리즈', 360),
#  ('대한', 357),
#  ('에는', 355),
#  ('좋다', 355),
#  ('이제', 355),
#  ('원작', 352),
#  ('연기력', 352),
#  ('개봉', 344),
#  ('처럼', 344),
#  ('솔직히', 343),
#  ('표현', 340),
#  ('중간', 338),
#  ('뭔가', 338),
#  ('기대', 335),
#  ('ㅋㅋㅋㅋ', 334),
#  ('진심', 331),
#  ('하면', 331),
#  ('이라', 330),
#  ('여운', 330),
#  ('이네', 328),
#  ('부분', 328),
#  ('대박', 327),
#  ('공감', 327),
#  ('였다', 325),
#  ('했다', 325),
#  ('일본', 324),
#  ('기분', 323),
#  ('ㅜㅜ', 320),
#  ('많은', 316),
#  ('나오는', 316),
#  ('아주', 315),
#  ('보지', 315),
#  ('전혀', 314),
#  ('가족', 314),
#  ('근데', 314),
#  ('영상', 312),
#  ('이랑', 311),
#  ('그런', 310),
#  ('제목', 307),
#  ('이라는', 306),
#  ('내내', 305),
#  ('없음', 304),
#  ('아니라', 303),
#  ('아닌', 303),
#  ('봤습니다', 302),
#  ('좋고', 298),
#  ('대사', 296),
#  ('아니다', 296),
#  ('건지', 295),
#  ('했는데', 294),
#  ('아니고', 294),
#  ('공포', 294),
#  ('애니', 293),
#  ('극장', 293),
#  ('요즘', 292),
#  ('재밌다', 291),
#  ('몰입', 287),
#  ('재미있게', 286),
#  ('점도', 284),
#  ('특히', 283),
#  ('밖에', 281),
#  ('재미없다', 281),
#  ('하다', 280),
#  ('작가', 279),
#  ('긴장감', 279),
#  ('나름', 278),
#  ('보면서', 277),
#  ('이란', 268),
#  ('않는', 268),
#  ('에도', 265),
#  ('한테', 263),
#  ('않은', 263),
#  ('의미', 262),
#  ('노래', 262),
#  ('오랜', 261),
#  ('친구', 261),
#  ('이지', 261),
#  ('시작', 260),
#  ('이유', 259),
#  ('해도', 259),
#  ('만드는', 259),
#  ('개인', 257),
#  ('아름다운', 256),
#  ('노잼', 254),
#  ('스릴러', 254),
#  ('보다가', 253),
#  ('당시', 252),
#  ('공포영화', 252),
#  ('아까운', 251),
#  ('우리나라', 251),
#  ('뻔한', 247),
#  ('영화로', 246),
#  ('알바', 245),
#  ('제일', 242),
#  ('보게', 241),
#  ('재밌어요', 241),
#  ('된다', 241),
#  ('이라고', 241),
#  ('아직도', 238),
#  ('점수', 238),
#  ('년대', 237),
#  ('엄청', 237),
#  ('세상', 234),
#  ('있고', 233),
#  ('웃음', 233),
#  ('아무', 231),
#  ('보세요', 231),
#  ('좋아하는', 230),
#  ('막장', 228),
#  ('제대로', 228),
#  ('시나리오', 226),
#  ('보니', 223),
#  ('싶다', 222),
#  ('출연', 220),
#  ('초반', 220),
#  ('시대', 217),
#  ('관객', 217),
#  ('봤어요', 217),
#  ('절대', 217),
#  ('미국', 216),
#  ('도대체', 216),
#  ('그렇게', 215),
#  ('분위기', 214),
#  ('같아요', 213),
#  ('대해', 213),
#  ('설정', 212),
#  ('위해', 212),
#  ('인상', 211),
#  ('재밌음', 211),
#  ('보는내내', 211),
#  ('사실', 210),
#  ('제발', 210),
#  ('최고다', 210),
#  ('나도', 208),
#  ('한국영', 207),
#  ('마다', 205),
#  ('봤던', 205),
#  ('졸작', 204),
#  ('장난', 203),
#  ('이딴', 202),
#  ('정신', 202),
#  ('주는', 201),
#  ('준다', 200),
#  ('어릴', 199),
#  ('영화관', 198),
#  ('주고', 197),
#  ('니까', 196),
#  ('좋았다', 196),
#  ('가지', 196),
#  ('남는', 196),
#  ('소리', 196),
#  ('지루하고', 195),
#  ('라면', 195),
#  ('더빙', 195),
#  ('멋진', 195),
#  ('감정', 194),
#  ('수작', 194),
#  ('후반', 194),
#  ('안되는', 192),
#  ('엄마', 192),
#  ('추억', 192),
#  ('아무리', 192),
#  ('좋아요', 191),
#  ('이야', 190),
#  ('갈수록', 189),
#  ('문제', 189),
#  ('옛날', 189),
#  ('이름', 188),
#  ('기도', 188),
#  ('개연', 188),
#  ('봐서', 187),
#  ('킬링타임', 187),
#  ('엔딩', 186),
#  ('오늘', 185),
#  ('코믹', 184),
#  ('싶은', 184),
#  ('충격', 180),
#  ('평가', 180),
#  ('지루함', 180),
#  ('스릴', 180),
#  ('얘기', 179),
#  ('애니메이션', 179),
#  ('포스터', 179),
#  ('역사', 178),
#  ('전쟁', 178),
#  ('그것', 176),
#  ('모르겠다', 175),
#  ('얼굴', 175),
#  ('캐스팅', 174),
#  ('배경', 174),
#  ('다큐', 172),
#  ('지루한', 172),
#  ('구성', 171),
#  ('소름', 171),
#  ('상황', 171),
#  ('했던', 169),
#  ('후회', 168),
#  ('예술', 167),
#  ('아직', 167),
#  ('괜찮은', 167),
#  ('영화인', 166),
#  ('보단', 165),
#  ('머리', 165),
#  ('티비', 165),
#  ('분들', 163),
#  ('장르', 163),
#  ('걸작', 162),
#  ('했지만', 162),
#  ('만들어', 161),
#  ('대체', 161),
#  ('않는다', 161),
#  ('않다', 161),
#  ('다운', 160),
#  ('주연', 160),
#  ('이후', 160),
#  ('강추', 159),
#  ('나온', 159),
#  ('시즌', 159),
#  ('하는데', 158),
#  ('건가', 158),
#  ('같은데', 157),
#  ('ㅉㅉ', 157),
#  ('만화', 157),
#  ('짜증', 157),
#  ('봤지만', 155),
#  ('비교', 154),
#  ('없었다', 154),
#  ('실화', 152),
#  ('집중', 152),
#  ('지루하다', 152),
#  ('보는데', 151),
#  ('인물', 151),
#  ('마세요', 150),
#  ('그나마', 150),
#  ('시절', 150),
#  ('없네', 150),
#  ('존나', 149),
#  ('억지', 149),
#  ('할수', 148),
#  ('웃기', 148),
#  ('만점', 148),
#  ('몰입도', 148),
#  ('방송', 147),
#  ('재밌는', 147),
#  ('너무나', 147),
#  ('초딩', 147),
#  ('아들', 147),
#  ('봤음', 146),
#  ('편이', 145),
#  ('같음', 144),
#  ('라도', 143),
#  ('주제', 143),
#  ('에요', 142),
#  ('목소리', 142),
#  ('네이버', 141),
#  ('매우', 140),
#  ('재미없음', 140),
#  ('비디오', 139),
#  ('그대로', 139),
#  ('저런', 138),
#  ('이리', 137),
#  ('본다', 137),
#  ('나이', 137),
#  ('전체', 137),
#  ('였습니다', 135),
#  ('없어', 135),
#  ('하기', 134),
#  ('나와서', 133),
#  ('로맨스', 133),
#  ('사회', 133),
#  ('나라', 133),
#  ('감성', 133),
#  ('굉장히', 132),
#  ('재밋', 132),
#  ('보다는', 132),
#  ('안보', 131),
#  ('아님', 131),
#  ('재밌고', 130),
#  ('가는', 130),
#  ('빨리', 130),
#  ('누가', 130),
#  ('년도', 129),
#  ('평론가', 129),
#  ('가치', 128),
#  ('없어서', 128),
#  ('상당히', 127),
#  ('예전', 127),
#  ('짜리', 127),
#  ('발연기', 126),
#  ('만하', 126),
#  ('해야', 126),
#  ('같네요', 126),
#  ('질질', 126),
#  ('이하', 125),
#  ('실제', 125),
#  ('하네요', 125),
#  ('소설', 125),
#  ('삼류', 125),
#  ('어렸을', 125),
#  ('보여주는', 124),
#  ('어설픈', 124),
#  ('여배우', 124),
#  ('년전', 124),
#  ('아버지', 123),
#  ('라서', 123),
#  ('아까', 123),
#  ('시청률', 123),
#  ('점주', 123),
#  ('좀비', 123),
#  ('어린', 122),
#  ('성룡', 122),
#  ('낭비', 121),
#  ('교훈', 120),
#  ('해주는', 120),
#  ('있지만', 120),
#  ('몇번', 119),
#  ('깊은', 119),
#  ('어른', 119),
#  ('간만', 118),
#  ('여서', 117),
#  ('극장판', 117),
#  ('여주', 117),
#  ('잔잔한', 117),
#  ('재미있어요', 117),
#  ('재밌네요', 117),
#  ('판타지', 117),
#  ('슬픈', 116),
#  ('상영', 116),
#  ('있어', 116),
#  ('난다', 115),
#  ('이에요', 115),
#  ('줄거리', 115),
#  ('버린', 115),
#  ('미친', 114),
#  ('는데', 114),
#  ('으로도', 114),
#  ('아까워', 114),
#  ('각본', 114),
#  ('항상', 114),
#  ('에선', 114),
#  ('전달', 113),
#  ('좋음', 113),
#  ('세계', 113),
#  ('중국', 113),
#  ('간다', 112),
#  ('ㅎㅎㅎ', 112),
#  ('믿고', 112),
#  ('라니', 112),
#  ('요소', 112),
#  ('좋은데', 112),
#  ('그만', 112),
#  ('멜로', 111),
#  ('되고', 111),
#  ('치고', 111),
#  ('재미있다', 111),
#  ('인거', 111),
#  ('점점', 111),
#  ('낫다', 111),
#  ('사건', 110),
#  ('말고', 109),
#  ('존재', 109),
#  ('대로', 109),
#  ('이라도', 109),
#  ('그런지', 109),
#  ('진정한', 108),
#  ('상상', 108),
#  ('흥행', 108),
#  ('선택', 108),
#  ('필요', 108),
#  ('순간', 108),
#  ('새끼', 107),
#  ('볼때', 107),
#  ('그림', 107),
#  ('개그', 107),
#  ('따뜻한', 107),
#  ('되어', 107),
#  ('대한민국', 107),
#  ('제작', 107),
#  ('만이', 107),
#  ('가서', 107),
#  ('화보', 107),
#  ('복수', 107),
#  ('더럽게', 107),
#  ('여러', 106),
#  ('나쁜', 106),
#  ('하네', 106),
#  ('에서도', 105),
#  ('거기', 105),
#  ('ㅠㅠㅠ', 105),
#  ('환상', 105),
#  ('이라니', 105),
#  ('병맛', 105),
#  ('거지', 104),
#  ('연기자', 104),
#  ('이냐', 104),
#  ('아빠', 103),
#  ('아쉽다', 103),
#  ('감상', 103),
#  ('스타', 103),
#  ('ㄷㄷ', 103),
#  ('아닌가', 103),
#  ('잘만', 103),
#  ('있는데', 103),
#  ('역대', 103),
#  ('좋겠다', 103),
#  ('의도', 102),
#  ('화면', 102),
#  ('충분히', 102),
#  ('하며', 102),
#  ('성우', 102),
#  ('에서는', 102),
#  ('상미', 101),
#  ('대단한', 101),
#  ('프랑스', 101),
#  ('였음', 101),
#  ('스러운', 101),
#  ('그녀', 101),
#  ('봐야', 100),
#  ('있어서', 100),
#  ('어쩔', 99),
#  ('액션영화', 99),
#  ('되지', 99),
#  ('엉망', 99),
#  ('천재', 99),
#  ('좋았어요', 99),
#  ('ㅋㅋㅋㅋㅋ', 99),
#  ('마무리', 99),
#  ('하는게', 99),
#  ('나온다', 99),
#  ('좋네요', 99),
#  ('갑자기', 98),
#  ('스타일', 98),
#  ('훌륭한', 98),
#  ('학교', 98),
#  ('참고', 97),
#  ('주의', 97),
#  ('없네요', 97),
#  ('영웅', 97),
#  ('원래', 97),
#  ('예고편', 97),
#  ('나오고', 97),
#  ('모르고', 96),
#  ('였어요', 96),
#  ('우연히', 96),
#  ('게임', 96),
#  ('엄청난', 96),
#  ('있게', 96),
#  ('완성', 96),
#  ('수가', 96),
#  ('바보', 95),
#  ('죽음', 95),
#  ('야할', 95),
#  ('에겐', 95),
#  ('더욱', 94),
#  ('안된다', 94),
#  ('한편', 94),
#  ('비해', 94),
#  ('해준', 94),
#  ('유치', 94),
#  ('그래픽', 94),
#  ('재미있는', 94),
#  ('알았는데', 94),
#  ('행동', 93),
#  ('재미없는', 93),
#  ('없을', 92),
#  ('완벽한', 92),
#  ('있음', 92),
#  ('화이팅', 92),
#  ('전편', 92),
#  ('자꾸', 92),
#  ('봤네요', 91),
#  ('꿀잼', 91),
#  ('어디서', 91),
#  ('대작', 91),
#  ('편집', 91),
#  ('했음', 90),
#  ('속편', 90),
#  ('하는지', 90),
#  ('그게', 90),
#  ('괜히', 89),
#  ('중반', 89),
#  ('같아', 89),
#  ('드는', 89),
#  ('무비', 88),
#  ('채널', 88),
#  ('보이', 88),
#  ('나옴', 88),
#  ('취향', 88),
#  ('기대하고', 88),
#  ('보는게', 88),
#  ('있을까', 88),
#  ('가끔', 87),
#  ('노출', 87),
#  ('먼저', 87),
#  ('자극', 87),
#  ('미화', 87),
#  ('재미없고', 87),
#  ('억지로', 87),
#  ('일까', 87),
#  ('경찰', 87),
#  ('새로운', 86),
#  ('나올', 86),
#  ('관심', 86),
#  ('흥미', 86),
#  ('댓글', 86),
#  ('알았다', 86),
#  ('진행', 86),
#  ('영환', 86),
#  ('화가', 86),
#  ('결혼', 85),
#  ('통해', 85),
#  ('했으면', 85),
#  ('심리', 84),
#  ('좋았습니다', 84),
#  ('메세지', 84),
#  ('한다는', 84),
#  ('오빠', 84),
#  ('슬프다', 84),
#  ('이상한', 84),
#  ('리메이크', 84),
#  ('같습니다', 83),
#  ('제작비', 83),
#  ('만으로도', 83),
#  ('소녀', 83),
#  ('로는', 83),
#  ('예상', 83),
#  ('만들', 83),
#  ('힘든', 83),
#  ('비슷한', 83),
#  ('전형', 83),
#  ('다가', 82),
#  ('좋았음', 82),
#  ('타임', 82),
#  ('노력', 82),
#  ('화려한', 82),
#  ('재미없어', 82),
#  ('예산', 81),
#  ('전작', 81),
#  ('관람', 81),
#  ('표정', 81),
#  ('봤을', 81),
#  ('깊게', 81),
#  ('용도', 81),
#  ('높은', 81),
#  ('과정', 80),
#  ('메디', 80),
#  ('재밌는데', 80),
#  ('효과', 80),
#  ('아저씨', 80),
#  ('끝나고', 80),
#  ('유머', 80),
#  ('흥미진진', 80),
#  ('재미있고', 80),
#  ('먹고', 79),
#  ('보고나서', 79),
#  ('아쉬운', 79),
#  ('일이', 79),
#  ('맞는', 79),
#  ('오래', 78),
#  ('최근', 78),
#  ('진실', 78),
#  ('촬영', 78),
#  ('나왔으면', 78),
#  ('좋았고', 78),
#  ('지루', 78),
#  ('재밌었다', 78),
#  ('형님', 77),
#  ('거리', 77),
#  ('느끼게', 77),
#  ('바람', 77),
#  ('무조건', 77),
#  ('되게', 77),
#  ('있었다', 77),
#  ('반개', 77),
#  ('귀신', 77),
#  ('예요', 77),
#  ('이런거', 77),
#  ('그리', 76),
#  ('보여준', 76),
#  ('재밌었음', 76),
#  ('필요없는', 76),
#  ('너무나도', 76),
#  ('로맨틱', 76),
#  ('리얼', 76),
#  ('볼수', 76),
#  ('동화', 76),
#  ('만에', 75),
#  ('만들었다', 75),
#  ('지루하지', 75),
#  ('보고싶다', 75),
#  ('안됨', 75),
#  ('과거', 75),
#  ('그렇고', 75),
#  ('다행', 75),
#  ('였는데', 75),
#  ('범인', 75),
#  ('프로그램', 75),
#  ('살인', 75),
#  ('유치하고', 74),
#  ('안나', 74),
#  ('안되고', 74),
#  ('케이블', 74),
#  ('서로', 74),
#  ('등장', 74),
#  ('이미', 74),
#  ('능력', 74),
#  ('않음', 74),
#  ('진부한', 74),
#  ('모르는', 74),
#  ('고생', 74),
#  ('만의', 74),
#  ('싫다', 74),
#  ('어린이', 73),
#  ('묘사', 73),
#  ('망작', 73),
#  ('재밌었어요', 73),
#  ('조연', 73),
#  ('나서', 73),
#  ('않아', 73),
#  ('살다', 73),
#  ('낮은', 73),
#  ('아름답고', 72),
#  ('카메라', 72),
#  ('했을', 72),
#  ('사극', 72),
#  ('나를', 72),
#  ('든다', 72),
#  ('느낄', 72),
#  ('스케일', 72),
#  ('없지만', 72),
#  ('전설', 72),
#  ('있습니다', 72),
#  ('보시길', 72),
#  ('도저히', 71),
#  ('불륜', 71),
#  ('깊이', 71),
#  ('대안', 71),
#  ('이런게', 71),
#  ('용이', 71),
#  ('나중', 71),
#  ('있을', 71),
#  ('감사합니다', 71),
#  ('이며', 70),
#  ('되었다', 70),
#  ('볼수록', 70),
#  ('로서', 70),
#  ('하는거', 70),
#  ('문화', 70),
#  ('독립영화', 69),
#  ('지루해', 69),
#  ('리뷰', 69),
#  ('아닌데', 69),
#  ('비극', 69),
#  ('역할', 69),
#  ('발견', 69),
#  ('잘못', 69),
#  ('섹스', 68),
#  ('볼거리', 68),
#  ('않게', 68),
#  ('설명', 68),
#  ('느껴지는', 68),
#  ('는걸', 68),
#  ('아닐까', 68),
#  ('인가요', 68),
#  ('굳이', 68),
#  ('같고', 68),
#  ('상상력', 67),
#  ('벌써', 67),
#  ('관계', 67),
#  ('상처', 67),
#  ('포장', 67),
#  ('현재', 67),
#  ('멋지다', 67),
#  ('프로', 67),
#  ('스럽다', 67),
#  ('그닥', 67),
#  ('남는다', 67),
#  ('청춘', 66),
#  ('감탄', 66),
#  ('자막', 66),
#  ('봤으면', 66),
#  ('빼고', 66),
#  ('있나', 66),
#  ('않나', 66),
#  ('보라', 66),
#  ('들어', 66),
#  ('홍보', 66),
#  ('없나', 66),
#  ('받고', 66),
#  ('지도', 66),
#  ('눈빛', 66),
#  ('용서', 66),
#  ('고민', 66),
#  ('커플', 65),
#  ('확실히', 65),
#  ('대단하다', 65),
#  ('박수', 65),
#  ('아니지만', 65),
#  ('봤다가', 65),
#  ('인정', 65),
#  ('쩐다', 65),
#  ('힐링', 65),
#  ('실감', 65),
#  ('유쾌한', 65),
#  ('않았다', 64),
#  ('필요없다', 64),
#  ('미소', 64),
#  ('있네요', 64),
#  ('메시지', 64),
#  ('수도', 64),
#  ('마라', 64),
#  ('새벽', 64),
#  ('같아서', 64),
#  ('있다는', 64),
#  ('뜬금', 64),
#  ('졸라', 64),
#  ('희망', 63),
#  ('미래', 63),
#  ('웃김', 63),
#  ('풀어', 63),
#  ('보러', 63),
#  ('좋아하는데', 63),
#  ('성인', 63),
#  ('받아', 63),
#  ('사는', 63),
#  ('좋았는데', 63),
#  ('봅니다', 63),
#  ('아름답다', 62),
#  ('보이는', 62),
#  ('할까', 62),
#  ('버리고', 62),
#  ('아픈', 62),
#  ('가볍게', 62),
#  ('흐름', 62),
#  ('아쉬움', 62),
#  ('인기', 62),
#  ('만들지', 62),
#  ('보고싶은', 62),
#  ('짜증나는', 62),
#  ('왠지', 62),
#  ('그럭저럭', 62),
#  ('범죄', 62),
#  ('ㅅㅂ', 62),
#  ('보시', 62),
#  ('무협', 62),
#  ('노답', 61),
#  ('주기', 61),
#  ('하냐', 61),
#  ('슬프고', 61),
#  ('서야', 61),
#  ('지난', 61),
#  ('독특한', 61),
#  ('생애', 61),
#  ('아오', 61),
#  ('괴물', 61),
#  ('부족', 61),
#  ('특유', 61),
#  ('정서', 61),
#  ('자유', 61),
#  ('성도', 61),
#  ('있으면', 60),
#  ('오버', 60),
#  ('버렸다', 60),
#  ('재밌습니다', 60),
#  ('종교', 60),
#  ('피해자', 60),
#  ('되네요', 60),
#  ('부족한', 60),
#  ('아침', 60),
#  ('개판', 59),
#  ('악당', 59),
#  ('편의', 59),
#  ('없는데', 59),
#  ('스럽게', 59),
#  ('사이', 59),
#  ('그렇다고', 59),
#  ('슬픔', 59),
#  ('진정', 59),
#  ('라지', 59),
#  ('평생', 59),
#  ('조폭', 59),
#  ('나와', 59),
#  ('남편', 59),
#  ('빠진', 59),
#  ('에서의', 59),
#  ('으로는', 59),
#  ('이쁘고', 59),
#  ('예쁜', 59),
#  ('유치한', 58),
#  ('어색한', 58),
#  ('신선한', 58),
#  ('몸매', 58),
#  ('오락', 58),
#  ('보다도', 58),
#  ('짱짱', 58),
#  ('방식', 58),
#  ('재미있음', 58),
#  ('하다니', 57),
#  ('일상', 57),
#  ('재밌어', 57),
#  ('결론', 57),
#  ('해피엔딩', 57),
#  ('없지', 57),
#  ('끼리', 57),
#  ('어제', 57),
#  ('등장인물', 57),
#  ('어휴', 57),
#  ('넘치는', 57),
#  ('왜케', 56),
#  ('않을', 56),
#  ('지는', 56),
#  ('아는', 56),
#  ('만으로', 56),
#  ('덕분', 56),
#  ('됩니다', 56),
#  ('하자', 56),
#  ('봤었는데', 56),
#  ('여성', 56),
#  ('군대', 56),
#  ('공부', 56),
#  ('웃긴', 56),
#  ('있다면', 56),
#  ('폭력', 56),
#  ('연예인', 56),
#  ('시청자', 56),
#  ('그린', 56),
#  ('해라', 55),
#  ('런가', 55),
#  ('자연', 55),
#  ('개념', 55),
#  ('에게는', 55),
#  ('잼있게', 55),
#  ('본다면', 55),
#  ('차이', 55),
#  ('만들고', 55),
#  ('살짝', 55),
#  ('평범한', 55),
#  ('외국', 55),
#  ('동생', 55),
#  ('기대했는데', 54),
#  ('귀여운', 54),
#  ('뛰어난', 54),
#  ('하고자', 54),
#  ('학생', 54),
#  ('ㅇㅇ', 54),
#  ('시선', 54),
#  ('낮아서', 54),
#  ('들었다', 54),
#  ('만들어진', 54),
#  ('까지는', 54),
#  ('반성', 54),
#  ('나머지', 54),
#  ('국민', 54),
#  ('비추', 54),
#  ('남녀', 54),
#  ('어이없는', 54),
#  ('되서', 53),
#  ('의식', 53),
#  ('떠나서', 53),
#  ('허세', 53),
#  ('북한', 53),
#  ('있어요', 53),
#  ('시도', 53),
#  ('드립니다', 53),
#  ('유발', 53),
#  ('세기', 53),
#  ('발전', 53),
#  ('펑펑', 53),
#  ('개도', 53),
#  ('대가', 53),
#  ('있지', 53),
#  ('가는줄', 53),
#  ('선생님', 53),
#  ('자식', 53),
#  ('무서운', 53),
#  ('보았다', 53),
#  ('나오네', 53),
#  ('평이', 53),
#  ('가고', 53),
#  ('대부분', 53),
#  ('극치', 52),
#  ('의문', 52),
#  ('그걸', 52),
#  ('연애', 52),
#  ('크게', 52),
#  ('기세', 52),
#  ('가진', 52),
#  ('까진', 52),
#  ('왠만하면', 52),
#  ('결과', 52),
#  ...]

# %%
vocab["영화"], vocab["너무"]
# Out:
# (17234, 3735)

# %%
# 전처리 함수
# 토큰화 함수 
# <UNK> -> 0번
# <PADDING> -> 1번
# 길이보고 잘라내는 것까지

# %%
# 데이터프레임으로 변환
vocabDF = pd.DataFrame.from_dict(vocab, orient="index")

vocabDF
# Out:
#          0
# 평점    2213
# 나쁘진     12
# 않지만     46
# 더욱      94
# 아니잖아    29
# ...    ...
# 박약       1
# 닮았고      1
# 이등병      1
# 높았지만     1
# 불안하게     1
#
# [52576 rows x 1 columns]

# %%
vocabDF = pd.DataFrame(vocabDF.sort_values(by=0, ascending=False))
vocabDF
# Out:
#              0
# 영화       17234
# 너무        3735
# 정말        3241
# 진짜        2927
# 평점        2213
# ...        ...
# 잡는것밖에        1
# 키얼스틴던스트      1
# 마인           1
# 물어봐도         1
# 불안하게         1
#
# [52576 rows x 1 columns]

# %% [markdown]
# # 3. 데이터셋용 단어사전/어휘사전 생성
# - 최종 사용할 단어 수
# - 특별한 의미의 문자 추가 : "<UNK>", "<PAD>"

# %%
VOCAB_DICT = {0:"<UNK>",
              1:"<PAD>"}

for idx in range(10):
    # print(vocabDF.iloc[idx])
    VOCAB_DICT[idx+2] = vocabDF.index[idx]
    
VOCAB_DICT # 2 : 단어1, 3: 단어2
# Out:
# {0: '<UNK>',
#  1: '<PAD>',
#  2: '영화',
#  3: '너무',
#  4: '정말',
#  5: '진짜',
#  6: '평점',
#  7: '연기',
#  8: '최고',
#  9: '생각',
#  10: '스토리',
#  11: '이다'}

# %%
# 문장을 수치화 진행 -> 인코딩
test = ["영화", "우히힛", "최고", "생각"]

sentence = []
for tt in test:
    sentence.append(0) # 없으면 왜 0 -> UNK 
    for k, v in VOCAB_DICT.items():
        if v == tt:
            sentence[-1] = k
            break
sentence
# Out:
# [2, 0, 8, 9]

# %%
# 수치값을 문자열로 변환 -> 디코딩
words = []
for tt in sentence:
    words.append(VOCAB_DICT.get(tt))
    
print(words)
# Out:
# ['영화', '<UNK>', '최고', '생각']
