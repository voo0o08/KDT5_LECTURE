# %% [markdown]
# # Dataset & DataLoader 살펴보기
# - Pytorch에서 배치크기만 데이터를 조절하기 위한 메커니즴
# - Dataset : 사용 데이터를 기반으로 사용자 정의 클래스 작성
# - DataLoader : 지정된 Datase에서 지정된 배치사이즈 만큼 피쳐와 타겟을 추출하여 전달

# %%
# 모듈 로딩
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, TensorDataset

import numpy as np
import pandas as pd

# %%
# 데이터 준비
x_data = torch.IntTensor([[10, 20, 30],[20, 30, 40],[30, 40, 50],[40, 50, 60], [50, 60, 70]])
y_data = torch.IntTensor([[20], [30], [40], [50], [60]])

#  행 길이는 꼭 맞춰줘야함!! 

print(f"x_data => {x_data.shape} {x_data.ndim}D")
print(f"y_data => {y_data.shape} {y_data.ndim}D")
# Out:
# x_data => torch.Size([5, 3]) 2D
# y_data => torch.Size([5, 1]) 2D

# %% [markdown]
# # 2. 데이터셋 생성

# %% [markdown]
# ## 2-1 TensorDataset 활용 : Dataset의 sub_class

# %%
# tensorDataset 클래스 로딩
from torch.utils.data import TensorDataset

# %%
dataset = TensorDataset(x_data, y_data)
dataset

# %%
dataset.tensors
# Out:
# (tensor([[10, 20, 30],
#          [20, 30, 40],
#          [30, 40, 50],
#          [40, 50, 60],
#          [50, 60, 70]], dtype=torch.int32),
#  tensor([[20],
#          [30],
#          [40],
#          [50],
#          [60]], dtype=torch.int32))

# %%
# __getitem__() 메서드 호출 
dataset[0] # x와 y의 첫번 째 요소들을 뽑아줌
# Out:
# (tensor([10, 20, 30], dtype=torch.int32), tensor([20], dtype=torch.int32))

# %%
len(dataset)
# Out:
# 5

# %% [markdown]
# ## 2-2 사용자 정의 데이터셋 생성

# %%
### data 준비
file = "../../EXAM_ML/data/iris.csv"

irisDF = pd.read_csv(file)
irisDF
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
# 넘파이로도 한번 열어보자
irisNP = np.loadtxt(file, delimiter="," ,skiprows=1, usecols=[0, 1, 2, 3])
irisNP
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
#        [5.2, 4.1, 1.5, 0.1],
#        [5.5, 4.2, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.2],
#        [5. , 3.2, 1.2, 0.2],
#        [5.5, 3.5, 1.3, 0.2],
#        [4.9, 3.6, 1.4, 0.1],
#        [4.4, 3. , 1.3, 0.2],
#        [5.1, 3.4, 1.5, 0.2],
#        [5. , 3.5, 1.3, 0.3],
#        [4.5, 2.3, 1.3, 0.3],
#        [4.4, 3.2, 1.3, 0.2],
#        [5. , 3.5, 1.6, 0.6],
#        [5.1, 3.8, 1.9, 0.4],
#        [4.8, 3. , 1.4, 0.3],
#        [5.1, 3.8, 1.6, 0.2],
#        [4.6, 3.2, 1.4, 0.2],
#        [5.3, 3.7, 1.5, 0.2],
#        [5. , 3.3, 1.4, 0.2],
#        [7. , 3.2, 4.7, 1.4],
#        [6.4, 3.2, 4.5, 1.5],
#        [6.9, 3.1, 4.9, 1.5],
#        [5.5, 2.3, 4. , 1.3],
#        [6.5, 2.8, 4.6, 1.5],
#        [5.7, 2.8, 4.5, 1.3],
#        [6.3, 3.3, 4.7, 1.6],
#        [4.9, 2.4, 3.3, 1. ],
#        [6.6, 2.9, 4.6, 1.3],
#        [5.2, 2.7, 3.9, 1.4],
#        [5. , 2. , 3.5, 1. ],
#        [5.9, 3. , 4.2, 1.5],
#        [6. , 2.2, 4. , 1. ],
#        [6.1, 2.9, 4.7, 1.4],
#        [5.6, 2.9, 3.6, 1.3],
#        [6.7, 3.1, 4.4, 1.4],
#        [5.6, 3. , 4.5, 1.5],
#        [5.8, 2.7, 4.1, 1. ],
#        [6.2, 2.2, 4.5, 1.5],
#        [5.6, 2.5, 3.9, 1.1],
#        [5.9, 3.2, 4.8, 1.8],
#        [6.1, 2.8, 4. , 1.3],
#        [6.3, 2.5, 4.9, 1.5],
#        [6.1, 2.8, 4.7, 1.2],
#        [6.4, 2.9, 4.3, 1.3],
#        [6.6, 3. , 4.4, 1.4],
#        [6.8, 2.8, 4.8, 1.4],
#        [6.7, 3. , 5. , 1.7],
#        [6. , 2.9, 4.5, 1.5],
#        [5.7, 2.6, 3.5, 1. ],
#        [5.5, 2.4, 3.8, 1.1],
#        [5.5, 2.4, 3.7, 1. ],
#        [5.8, 2.7, 3.9, 1.2],
#        [6. , 2.7, 5.1, 1.6],
#        [5.4, 3. , 4.5, 1.5],
#        [6. , 3.4, 4.5, 1.6],
#        [6.7, 3.1, 4.7, 1.5],
#        [6.3, 2.3, 4.4, 1.3],
#        [5.6, 3. , 4.1, 1.3],
#        [5.5, 2.5, 4. , 1.3],
#        [5.5, 2.6, 4.4, 1.2],
#        [6.1, 3. , 4.6, 1.4],
#        [5.8, 2.6, 4. , 1.2],
#        [5. , 2.3, 3.3, 1. ],
#        [5.6, 2.7, 4.2, 1.3],
#        [5.7, 3. , 4.2, 1.2],
#        [5.7, 2.9, 4.2, 1.3],
#        [6.2, 2.9, 4.3, 1.3],
#        [5.1, 2.5, 3. , 1.1],
#        [5.7, 2.8, 4.1, 1.3],
#        [6.3, 3.3, 6. , 2.5],
#        [5.8, 2.7, 5.1, 1.9],
#        [7.1, 3. , 5.9, 2.1],
#        [6.3, 2.9, 5.6, 1.8],
#        [6.5, 3. , 5.8, 2.2],
#        [7.6, 3. , 6.6, 2.1],
#        [4.9, 2.5, 4.5, 1.7],
#        [7.3, 2.9, 6.3, 1.8],
#        [6.7, 2.5, 5.8, 1.8],
#        [7.2, 3.6, 6.1, 2.5],
#        [6.5, 3.2, 5.1, 2. ],
#        [6.4, 2.7, 5.3, 1.9],
#        [6.8, 3. , 5.5, 2.1],
#        [5.7, 2.5, 5. , 2. ],
#        [5.8, 2.8, 5.1, 2.4],
#        [6.4, 3.2, 5.3, 2.3],
#        [6.5, 3. , 5.5, 1.8],
#        [7.7, 3.8, 6.7, 2.2],
#        [7.7, 2.6, 6.9, 2.3],
#        [6. , 2.2, 5. , 1.5],
#        [6.9, 3.2, 5.7, 2.3],
#        [5.6, 2.8, 4.9, 2. ],
#        [7.7, 2.8, 6.7, 2. ],
#        [6.3, 2.7, 4.9, 1.8],
#        [6.7, 3.3, 5.7, 2.1],
#        [7.2, 3.2, 6. , 1.8],
#        [6.2, 2.8, 4.8, 1.8],
#        [6.1, 3. , 4.9, 1.8],
#        [6.4, 2.8, 5.6, 2.1],
#        [7.2, 3. , 5.8, 1.6],
#        [7.4, 2.8, 6.1, 1.9],
#        [7.9, 3.8, 6.4, 2. ],
#        [6.4, 2.8, 5.6, 2.2],
#        [6.3, 2.8, 5.1, 1.5],
#        [6.1, 2.6, 5.6, 1.4],
#        [7.7, 3. , 6.1, 2.3],
#        [6.3, 3.4, 5.6, 2.4],
#        [6.4, 3.1, 5.5, 1.8],
#        [6. , 3. , 4.8, 1.8],
#        [6.9, 3.1, 5.4, 2.1],
#        [6.7, 3.1, 5.6, 2.4],
#        [6.9, 3.1, 5.1, 2.3],
#        [5.8, 2.7, 5.1, 1.9],
#        [6.8, 3.2, 5.9, 2.3],
#        [6.7, 3.3, 5.7, 2.5],
#        [6.7, 3. , 5.2, 2.3],
#        [6.3, 2.5, 5. , 1.9],
#        [6.5, 3. , 5.2, 2. ],
#        [6.2, 3.4, 5.4, 2.3],
#        [5.9, 3. , 5.1, 1.8]])

# %%
irisDF.__class__.__name__, irisNP.__class__.__name__
# Out:
# ('DataFrame', 'ndarray')

# %%
isinstance(irisDF, pd.DataFrame), isinstance(irisNP, np.ndarray), isinstance([1, 2], list)
# Out:
# (True, True, True)

# %%
# 사용자 정의 DataSet Class
# Dataset = 부모 
# DLDataset = 자식
# 데이터의 텐서변환
class DLDataset(Dataset):
    
    # 초기화 함수
    def __init__(self, x_data, y_data):
        super().__init__()
        # x, y 데이터 => ndarray
        x_data = x_data.values if isinstance(x_data, pd.DataFrame) else x_data # 데이터 프레임이라면 valuse로 어레이 뽑아줘야함 
        y_data = y_data.values if isinstance(y_data, pd.DataFrame) else y_data 
        
        # ndarray => tensor 
        self.feature = torch.FloatTensor(x_data)
        self.target = torch.LongTensor(y_data)
        
    # 데이터셋의 개수 체크 함수
    def __len__(self):
        return self.target.shape[0]
    
    # 특정 인덱스 데이터 + 라벨 반환 callback function 
    def __getitem__(self, index):
        return self.feature[index], self.target[index] # 둘 다 튜플로 출동

# %%
# feature와 label 분리 
featureDF = irisDF[irisDF.columns[:-1]]
targetNP = irisDF[irisDF.columns[-1]]

from sklearn.preprocessing import LabelEncoder # object 타입 타겟 => int 타입 타겟 변환 

print(f"featureDF => {featureDF.shape}, {featureDF.ndim}D")
print(f"targetDF => {targetNP.shape}, {targetNP.ndim}D")

targetNP = LabelEncoder().fit_transform(targetNP).reshape(-1, 1)
print(f"targetDF => {targetNP.shape}, {targetNP.ndim}D")
# Out:
# featureDF => (150, 4), 2D
# targetDF => (150,), 1D
# targetDF => (150, 1), 2D

# %%
my_dataset = DLDataset(featureDF, targetNP) # DF, numpy

# %%
my_dataset[0], featureDF.iloc[0], targetNP[0]
# Out:
# ((tensor([5.1000, 3.5000, 1.4000, 0.2000]), tensor([0])),
#  sepal.length    5.1
#  sepal.width     3.5
#  petal.length    1.4
#  petal.width     0.2
#  Name: 0, dtype: float64,
#  array([0]))

# %%
my_dataset2 = DLDataset(irisNP, targetNP) # numpy, numpy

# %% [markdown]
# ## 2-3 학습용, 검증용, 테스트용 Dataset

# %%
### => 파이토치
from torch.utils.data import random_split

# 데이터 비율 정하기 
seed = torch.Generator().manual_seed(42)
trainDS, validDS, testDS = random_split(my_dataset2, [0.7, 0.1, 0.2], generator=seed) # 개수로 주던가 비율로 주던가

print(f"trainDS => {len(trainDS)}개, validDS => {len(validDS)}개, testDS => {len(testDS)}개")
# Out:
# trainDS => 105개, validDS => 15개, testDS => 30개

# %%
print(f"Subset 속성 => {trainDS.indices}\ndataset => {trainDS.dataset}")
# Out:
# Subset 속성 => [42, 95, 30, 64, 52, 35, 130, 40, 82, 17, 108, 94, 68, 97, 117, 127, 41, 44, 57, 140, 149, 32, 23, 102, 16, 113, 71, 18, 67, 66, 0, 25, 101, 112, 91, 3, 59, 116, 86, 84, 106, 142, 43, 39, 26, 98, 93, 20, 87, 19, 120, 114, 7, 63, 76, 89, 36, 45, 37, 56, 58, 122, 51, 145, 24, 21, 105, 62, 15, 11, 48, 133, 88, 50, 6, 134, 111, 8, 49, 75, 69, 124, 4, 147, 80, 100, 99, 141, 47, 107, 13, 109, 129, 28, 38, 53, 121, 5, 55, 31, 73, 74, 54, 29, 12]
# dataset => <__main__.DLDataset object at 0x0000021BEAE027F0>

# %% [markdown]
# 전체 데이터 셋 => 학습DS, 테스터DS, 검증DF
# 속성 : index가 저장되어 있음

# %% [markdown]
# ## DataLoader 생성 : 학습용, 검증용, 테스트용

# %%
# DataLoader 생성
# drop_last 매개변수 : 배치사이즈로 데이터셋 분리 후 남는 데이터 처리 방법 설정 (default = False) True하면 걍 버리는 거임(valid로 쓸 데이터 없는 경우 버린 걸 사용하는 경우가 있음 )
batch_size = 5
trainDL = DataLoader(trainDS, batch_size=batch_size)
validDL = DataLoader(validDS, batch_size=batch_size)
testDL = DataLoader(testDS, batch_size=batch_size)

len(trainDL), len(validDL), len(testDL) # 배치사이즈 만큼 나눠진 수가 나오는 거임 즉, 1에포크 당 반복을 몇번하는지 알 수 있는 것
# Out:
# (21, 3, 6)

# %%
# Epoch당 반복 단위
print(f"Batch_size : {batch_size}")
print(f"trainDS => {len(trainDS)}개, validDS => {len(validDS)}개, testDS => {len(testDS)}개")
print(f"trainDL => {len(trainDL)}개, validDL => {len(validDL)}개, testDL => {len(testDL)}개")
# Out:
# Batch_size : 5
# trainDS => 105개, validDS => 15개, testDS => 30개
# trainDL => 21개, validDL => 3개, testDL => 6개

# %%
# DataLoader 생성
for _, (feature, target) in enumerate(trainDL):
    print(f"[{_}] feature {feature.shape}")
    ## 로더에서 가지고 온 데이터 만큼 학습 진행 
    ## 학습 후에는 검증도 할 것!
# Out:
# [0] feature torch.Size([5, 4])
# [1] feature torch.Size([5, 4])
# [2] feature torch.Size([5, 4])
# [3] feature torch.Size([5, 4])
# [4] feature torch.Size([5, 4])
# [5] feature torch.Size([5, 4])
# [6] feature torch.Size([5, 4])
# [7] feature torch.Size([5, 4])
# [8] feature torch.Size([5, 4])
# [9] feature torch.Size([5, 4])
# [10] feature torch.Size([5, 4])
# [11] feature torch.Size([5, 4])
# [12] feature torch.Size([5, 4])
# [13] feature torch.Size([5, 4])
# [14] feature torch.Size([5, 4])
# [15] feature torch.Size([5, 4])
# [16] feature torch.Size([5, 4])
# [17] feature torch.Size([5, 4])
# [18] feature torch.Size([5, 4])
# [19] feature torch.Size([5, 4])
# [20] feature torch.Size([5, 4])

# %%
trainDL

# %% [markdown]
# ## 4. Model 클래스 정의 : 입출력 feature 수, 층 수, 은닉층의 노드 수
#     * 입력층 : 입력 <= 피쳐 개수, iris 4개
#     * 은닉층 : 마음대로 알아서 잘
#     * 출력층 : 출력 <= 분류 = 타겟 클래스 수만큼 / 회귀 = 무조건 1개

# %%
import pandas
import numpy as np

import torch
import torch.nn as nn # linear Regression 기능의 클래스 Linear
import torch.nn.functional as F # 손실함수를 위함
import torch.optim as optim # 최적화를 위함

# %%
class CModel(nn.Module):
    # 구성요소 정의 함수
    def __init__(self, in_dim, out_dim):
        super().__init__()
        self.input_layer = nn.Linear(in_dim, 100)
        self.relu = nn.ReLU() # 활성화 함수 
        self.hidden_layer = nn.Linear(100, 27)
        self.output_layer = nn.Linear(27, out_dim)
        
    # 순방향 학습 진행 함수 
    def forward(self, x):
        x = self.input_layer(x) # W1x1 + W2x2... WnXn + b 반환 -> 이렇 게 생긴 거 100개 반환
        x = self.relu(x) # 결과 100개 반환
        x = self.hidden_layer(x) # W1x1 + W2x2... WnXn + b 반환 -> 이렇 게 생긴 거 27개 반환
        x = self.relu(x)
        x = self.output_layer(x)
        return x

# %% [markdown]
# # 5. 학습 준비 : 실행디바이스, 모델, 최적화, 손실함수, 학습 횟수, 학습 함수, 예측 함수

# %%
# 실행 디바이스 설정
DEVICE = "cuda" if torch.cuda.is_available() else "cpu" # GPU있으면 쓰고 없으면 cpu로 

# 학습 횟수
EPOCHS = 50

# %%
# 모델 인스턴스
IN, OUT = my_dataset2.feature.shape[1], len(my_dataset2.target.unique())
model = CModel(IN, OUT).to(DEVICE) # 어디다가 할 건지? ㅇㅅㅇ

# %%
my_dataset2.feature.shape[1], len(my_dataset2.target.unique())
# Out:
# (4, 3)

# %%
# 손실함수 인스턴스 
LOSS_FN = nn.CrossEntropyLoss().to(DEVICE) # 다중분류니까

# 최적화 인스턴스
OPTIMIZER = optim.Adam(model.parameters())

# %% [markdown]
# - 학습 및 검증관련 함수 정의

# %%
# 학습 진행함수
def training():
    # 학습 모드 => 정규화 , 경사 하강법, drop out 등의 기능 활성화
    model.train()
    
    # 배치크기 만큼 학습 진행 및 저장 
    train_loss = []
    for cnt, (feature, target) in enumerate(trainDL):
        # print(cnt, feature, target)
        # 배치크기만큼의 학습 데이터 준비 
        feature, target = feature.to(DEVICE), target.to(DEVICE)
        target = target.squeeze()
    
        # 학습 
        pre_target = model(feature)
        print(f"pre_target => {pre_target.shape}, {pre_target.ndim}D")
        print(f"target => {target.shape}, {target.ndim}D")
        
        # 손실계산
        loss = LOSS_FN(pre_target, target)
        train_loss.append(loss)
        
        # W, b 업데이트
        OPTIMIZER.zero_grad() # 초기화
        loss.backward() 
        OPTIMIZER.step()
        
        # 배치 단위 학습 진행 메시지 출력 
        # print(f"[train batch loss] => {loss}")
        
    # 학습 진행 메시지 출력
    print(f"[Train loss] ==> {loss}")
    
    return train_loss

# %%
# 검증 및 평가 진행 함수
def testing():
    pass

# %%
# 예측
def predict():
    pass

# %% [markdown]
# # 6. 학습 진행

# %%
for eps in range(EPOCHS):
    train_loss = training() # 학습
    # testing() # 검증
    
    print(f"[{eps}/{EPOCHS}] {sum(train_loss)/len(train_loss)}")
# Out:
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.8324071764945984
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 1.2762203216552734
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 1.307835578918457
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 1.4300241470336914
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 1.4385591745376587
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.9706686735153198
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 1.2428241968154907
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.9849313497543335
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 1.1915346384048462
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.9282970428466797
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 1.076833724975586
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.9780987501144409
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 1.0525424480438232
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 1.018050193786621
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.9967395663261414
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 1.0332958698272705
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 1.0147364139556885
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 1.0350068807601929
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 1.0054432153701782
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.9749526977539062
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.988493800163269
# [Train loss] ==> 0.988493800163269
# [0/50] 1.0846426486968994
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.9894899129867554
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.9354035258293152
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.9586469531059265
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.9677356481552124
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.8924309015274048
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.9459208250045776
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.9124442338943481
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.9470565915107727
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.8767095804214478
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.9064213633537292
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.8909519910812378
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.8552940487861633
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.8835444450378418
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.7834596037864685
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.8441481590270996
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.8409411311149597
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.8637073636054993
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.8532861471176147
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.778596818447113
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.8006914258003235
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.8235864639282227
# [Train loss] ==> 0.8235864639282227
# [1/50] 0.8833556175231934
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.8223265409469604
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.7107945680618286
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.8280900716781616
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.8116525411605835
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.671958327293396
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.7830815315246582
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.728988766670227
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.7964794039726257
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.6525658369064331
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.712917685508728
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.7263831496238708
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.6262847185134888
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.7227376699447632
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.5426329970359802
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.6560651063919067
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.6458476781845093
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.7080361843109131
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.6873300671577454
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.5453612208366394
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.6163155436515808
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.6525896191596985
# [Train loss] ==> 0.6525896191596985
# [2/50] 0.6975447535514832
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.008004335686564445
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.07367871701717377
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.003075564978644252
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.01435447484254837
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.013165880925953388
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.006125789135694504
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.006431195884943008
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.0008371688309125602
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.17480017244815826
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.006237237714231014
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.024592220783233643
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.03591027855873108
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.06544286757707596
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.032080937176942825
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.01379559375345707
# [Train loss] ==> 0.01379559375345707
# [46/50] 0.038254089653491974
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.004493880085647106
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.0012190407142043114
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.23283526301383972
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.0383632630109787
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.005473547615110874
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.03788498789072037
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.00758490851148963
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.07183422148227692
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.0029432151932269335
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.0140161644667387
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.012700000777840614
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.005884905345737934
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.0059848325327038765
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.0007922764052636921
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.16972272098064423
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.005700787529349327
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.02316391095519066
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.034136079251766205
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.06240074709057808
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.03161196783185005
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.01346037071198225
# [Train loss] ==> 0.01346037071198225
# [47/50] 0.03724795579910278
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.00431353785097599
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.001155894948169589
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.23150834441184998
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.037465114146471024
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.005258906167000532
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.03685794025659561
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.0072458297945559025
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.07009545713663101
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.002842364367097616
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.013292143121361732
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.012104226276278496
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.0056031327694654465
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.005902120377868414
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.0007484328234568238
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.17311929166316986
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.005542813800275326
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.02237234264612198
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.03375517576932907
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.062207359820604324
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.030351310968399048
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.012844115495681763
# [Train loss] ==> 0.012844115495681763
# [48/50] 0.03688504174351692
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.00409327307716012
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.0010941462824121118
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.23179157078266144
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.03719813749194145
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.005103028379380703
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.03564257174730301
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.006840463727712631
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.06825233995914459
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.0027160258032381535
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.013095825910568237
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.01168318185955286
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.005371201783418655
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.005455879960209131
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.0007099892827682197
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.16653214395046234
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.005066258367151022
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.021486084908246994
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.03245991840958595
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.059389691799879074
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.029955541715025902
# pre_target => torch.Size([5, 3]), 2D
# target => torch.Size([5]), 1D
# [train batch loss] => 0.012561887502670288
# [Train loss] ==> 0.012561887502670288
# [49/50] 0.03602377697825432

# %%
# # SoftMax 회귀 모델 클래스 생성
# class irisModel(nn.Module):
#     def __init__(self, in_, out_):
#         super(irisModel, self).__init__() # 부모 클래스 호로롥
#         self.layers = nn.Sequential( 
#             nn.Linear(in_, 256),
#             nn.ReLU(),
#             nn.Linear(256, 128),
#             nn.ReLU(),
#             nn.Linear(128, 64),
#             nn.ReLU(),
#             nn.Linear(64, out_)
#         )
#         
#     def forward(self, x): # 순전파 학습
#         x = self.layers(x)
#         return x # 소프트맥스는 loss fuction안에

# %%
# # 모델 인스턴스 생성
# model = irisModel(4, 3)
# 
# 
# # 최적화 함수 정의 
# optimizer = optim.Adam(model.parameters(), lr=0.01)

# %%
# # 학습 수행 
# loss_accuracy = [[], []]
# EPOCHS = 100
# 
# for _, (feature, target) in enumerate(trainDL):
#     # feature = feature.float()
#     # target = target.float()
#     # target = target.squeeze()     
#     pre_y = model(feature.float())
#     
#     # 오차 (손실) 계산
#     loss = F.cross_entropy(pre_y, target)
#     loss_accuracy[0].append(loss.item())
#     
#     # W, b 업데이트
#     optimizer.zero_grad()
#     loss.backward()
#     optimizer.step()
#     
#     # 정확도 계산
#     train_accuracy = (pre_y.argmax(dim=1)  == feature.argmax(dim=1)).sum() / feature.shape[0]
#     loss_accuracy[1].append(train_accuracy)
# 
#     print(f"[{_+1}/{_}] Loss: {loss.item():.4f}, Accuracy: {train_accuracy:.4f}")
